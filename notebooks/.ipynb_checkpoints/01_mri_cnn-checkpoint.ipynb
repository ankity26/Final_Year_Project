# %%
import os
import cv2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms
import matplotlib.pyplot as plt
# Out:
# --------------------------------------------------------
# ModuleNotFoundError    Traceback (most recent call last)
# Cell In[2], line 4
#       2 import cv2
#       3 import numpy as np
# ----> 4 import torch
#       5 import torch.nn as nn
#       6 import torch.optim as optim
#
# ModuleNotFoundError: No module named 'torch'

# %%
# Custom Dataset class
class MRIDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.image_files = [f for f in os.listdir(image_dir) if f.endswith('.png')]
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.image_dir, img_name)
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        # Normalize and convert to tensor
        if self.transform:
            image = self.transform(image)
        else:
            image = torch.tensor(image / 255.0, dtype=torch.float32).unsqueeze(0)
        
        # TEMP: all labels = 0 (we’ll add real labels later)
        label = 0  
        return image, label
# Out:
# --------------------------------------------------------
# NameError              Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Custom Dataset class
# ----> 2 class MRIDataset(Dataset):
#       3     def __init__(self, image_dir, transform=None):
#       4         self.image_dir = image_dir
#
# NameError: name 'Dataset' is not defined

# %%
# Transforms & dataset loading
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((128, 128)),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

dataset = MRIDataset("../data/processed", transform=transform)

# Split into train/validation
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8)
# Out:
# --------------------------------------------------------
# NameError              Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Transforms & dataset loading
# ----> 2 transform = transforms.Compose([
#       3     transforms.ToTensor(),
#       4     transforms.Resize((128, 128)),
#       5     transforms.Normalize(mean=[0.5], std=[0.5])
#       6 ])
#       8 dataset = MRIDataset("../data/processed", transform=transform)
#      10 # Split into train/validation
#
# NameError: name 'transforms' is not defined

# %%
# Define a small CNN
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(32*32*32, 64),
            nn.ReLU(),
            nn.Linear(64, 2)   # 2 classes (Normal vs AD) – temporary
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.fc_layers(x)
        return x

model = SimpleCNN()
print(model)
# Out:
# --------------------------------------------------------
# NameError              Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Define a small CNN
# ----> 2 class SimpleCNN(nn.Module):
#       3     def __init__(self):
#       4         super(SimpleCNN, self).__init__()
#
# NameError: name 'nn' is not defined

# %%
# Training loop (demo run)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(2):  # just test with 2 epochs
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    print(f"Epoch [{epoch+1}/2], Loss: {running_loss/len(train_loader):.4f}")
# Out:
# --------------------------------------------------------
# NameError              Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Training loop (demo run)
# ----> 2 criterion = nn.CrossEntropyLoss()
#       3 optimizer = optim.Adam(model.parameters(), lr=0.001)
#       5 for epoch in range(2):  # just test with 2 epochs
#
# NameError: name 'nn' is not defined
